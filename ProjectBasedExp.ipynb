# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

data = pd.read_excel("FacebookPosts.xlsx")

print(data.head())
print(data.columns)
# Out:
#                                    Timeline
# 0          I am very happy with this event!
# 1    The service was excellent and amazing.
# 2  I am disappointed with the poor service.
# 3           This is a wonderful experience.
# 4             The event was boring and bad.
# Index(['Timeline'], dtype='str')

# %%
from textblob import TextBlob
import matplotlib.pyplot as plt

# %%
def get_sentiment(text):
    analysis = TextBlob(str(text))
    
    if analysis.sentiment.polarity > 0:
        return "Positive"
    elif analysis.sentiment.polarity < 0:
        return "Negative"
    else:
        return "Neutral"

# %%
data['Sentiment'] = data['Timeline'].apply(get_sentiment)

print(data)
# Out:
#                                     Timeline Sentiment
# 0           I am very happy with this event!  Positive
# 1     The service was excellent and amazing.  Positive
# 2   I am disappointed with the poor service.  Negative
# 3            This is a wonderful experience.  Positive
# 4              The event was boring and bad.  Negative
# 5       Ramya had a great time at the event.  Positive
# 6       I really enjoyed this beautiful day.  Positive
# 7            Ramya is happy with the result.  Positive
# 8                  The service was terrible.  Negative
# 9              Today was an okay experience.  Positive
# 10                Ramya loved the new event.  Positive
# 11  I am unhappy with the poor organization.  Negative

# %%
sentiment_counts = data['Sentiment'].value_counts()

print(sentiment_counts)
# Out:
# Sentiment
# Positive    8
# Negative    4
# Name: count, dtype: int64

# %%
name = "Ramya"

count = data['Timeline'].str.lower().str.count(name.lower()).sum()

print("Number of occurrences of", name, ":", count)
# Out:
# Number of occurrences of Ramya : 3

# %%
plt.bar(sentiment_counts.index, sentiment_counts.values)
plt.title("Facebook Comments Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Number of Comments")
plt.show()
